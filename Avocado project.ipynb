# %%
#importing all the necessary library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#importing the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset

df=pd.read_csv("avocado.csv",index_col='Unnamed: 0')

# %%
df
# Out:
#            Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0.0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1.0  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2.0  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3.0  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4.0  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ..          ...           ...           ...      ...        ...     ...
# NaN         NaN           NaN           NaN      NaN        NaN     NaN
# NaN         NaN           NaN           NaN      NaN        NaN     NaN
# NaN         NaN           NaN           NaN      NaN        NaN     NaN
# NaN         NaN           NaN           NaN      NaN        NaN     NaN
# NaN         NaN           NaN           NaN      NaN        NaN     NaN
#
#      Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# ...

# %%
df.shape
# Out:
# (16468, 13)

# %%
# Checking the various columns

df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
#Checking the data types of the columns

df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
df.dropna(how = "any", inplace = True) # dropping all the rows which are null

# %%
#Checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1517 entries, 0.0 to 14.0
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   float64
#  12  region        1517 non-null   object
# dtypes: float64(10), object(3)
# memory usage: 165.9+ KB

# %% [markdown]
# Observation:
#
# 1.Total 16468 rows and 14 columns are present where 1517 rows with non-null values.
#
# 2.All the columns are in float64 data type except Date, Type and region columns as these are in object type.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %% [markdown]
# Observation:
#
# 1.Standard Deviation is maximum in Total Bags.
#
# 2.Minimum Average Price is 049 and Maximum Average Price is 1.68
#
# 3.In Total Volume,4046,4225,Total Bags,Small Bags,XLarge Bags columns the difference between 75% and max is more so in these columns outliers may be present.

# %% [markdown]
# # Checking For Missing Values

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# Observation:
#
# There is no null values in our dataset.

# %%
# Seeing the null values with the help of heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),annot=True)

# %% [markdown]
# # To check Correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# ...

# %% [markdown]
# Observation:
#
# Here we can see the correlation between the columns

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_cor,annot=True)

# %% [markdown]
# Observation:
#
# 1.Here we can see that no column has very high or very low correlation with target variable 'Average Price', so all are equally important.So it's better to keep all the columns.
#
# 2.Total bag, Small bag ,Large bag,4770,4225 are highly correlated.
#
# 3.The graph shows high multi-colinearity between independent variables.Few are highlighted below:
#     Total Volume & 4046, Total Volume & 4225, Total Volume & Large Bags, Small Bags & Total Bags.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariate Analysis

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
df['AveragePrice'].plot.bar()
plt.ylabel('Average Price')
plt.xlabel('No. of Rows')
plt.xticks(rotation=45)
plt.title('Average Price decripition')
plt.show()

# %%
plt.figure(figsize=(15,15))
df['Total Volume'].plot.bar()
plt.ylabel('Total Volume')
plt.xlabel('No. of Rows')
plt.xticks(rotation=45)
plt.title('Total Volume decripition')
plt.show()

# %%
df['Total Volume'].plot.hist(bins=20)
plt.title('Histogram of Total Volume')
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(df['Total Volume'])
plt.show()

# %% [markdown]
# Observation:
#
# There is a skewness in the Total Volume.

# %%
df['4046'].plot.hist(bins=20)
plt.title('Histogram of 4046')
plt.show()

# %%
df['4225'].plot.hist(bins=20)
plt.title('Histogram of 4225')
plt.show()

# %%
df['4770'].plot.hist(bins=20)
plt.title('Histogram of 4770')
plt.show()

# %%
df['Total Bags'].plot.hist(bins=20)
plt.title('Histogram of Total Bags')
plt.show()

# %%
df['Small Bags'].plot.hist(bins=20)
plt.title('Histogram of Small Bags')
plt.show()

# %%
df['Large Bags'].plot.hist(bins=20)
plt.title('Histogram of Large Bags')
plt.show()

# %%
df['XLarge Bags'].plot.hist(bins=20)
plt.title('Histogram of XLarge Bags')
plt.show()

# %%
df['type'].plot.hist(bins=20)
plt.title('Histogram of type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-42b93d8b33b6> in <module>
# ----> 1 df['type'].plot.hist(bins=20)
#       2 plt.title('Histogram of type')
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, by, bins, **kwargs)
#    1178             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1179         """
# -> 1180         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1181
#    1182     def kde(self, bw_method=None, ind=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...
